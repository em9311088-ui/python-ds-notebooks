# %% [markdown]
# # 09 — Exercise Solutions (Foundations)
#
# Solutions for practice tasks from notebooks 01–04.

# %% [markdown]
# ## Solution: Favorite number and city

# %%
favorite_number = 7
city = "Nairobi"
print(f"My favorite number is {favorite_number} and my city is {city}.")
# Out:
# My favorite number is 7 and my city is Nairobi.

# %% [markdown]
# ## Solution: is_even(n)

# %%
def is_even(n):
    return n % 2 == 0

for value in [1, 2, 15, 20]:
    print(value, is_even(value))
# Out:
# 1 False
# 2 True
# 15 False
# 20 True

# %% [markdown]
# ## Solution: Number → cube dictionary

# %%
cubes = {n: n**3 for n in range(1, 6)}
cubes
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}

# %% [markdown]
# ## Solution: safe_divide(a, b)

# %%
def safe_divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return "Cannot divide by zero"

print(safe_divide(10, 2))
print(safe_divide(10, 0))
# Out:
# 5.0
# Cannot divide by zero
