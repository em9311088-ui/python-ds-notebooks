# %% [markdown]
# # 01 — Python Fundamentals
#
# ## Learning goals
# - Understand variables, basic data types, and expressions
# - Practice input/output and type conversion
# - Write simple control flow

# %%
# Variables and basic types
name = "Kevin"
age = 28
height_m = 1.75
is_learning = True

print(name, age, height_m, is_learning)
print(type(name), type(age), type(height_m), type(is_learning))
# Out:
# Kevin 28 1.75 True
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
# Arithmetic and string formatting
x, y = 12, 5
print("Addition:", x + y)
print("Division:", x / y)
print("Floor division:", x // y)
print("Power:", x ** y)

print(f"{name} is {age} years old.")
# Out:
# Addition: 17
# Division: 2.4
# Floor division: 2
# Power: 248832
# Kevin is 28 years old.

# %%
# 1) Create variables
favorite_number = 7
favorite_city = "Tokyo"

# 2) Print a sentence combining them
print(f"My favorite number is {favorite_number} and my favorite city is {favorite_city}.")
# Out:
# My favorite number is 7 and my favorite city is Tokyo.
