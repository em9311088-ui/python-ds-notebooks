# %% [markdown]
# <a href="https://colab.research.google.com/github/em9311088-ui/python-ds-notebooks/blob/edwin--submission/04_files_exceptions_and_modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04 — Files, Exceptions, and Modules
#
# ## Learning goals
# - Read and write files
# - Handle errors with try/except
# - Import and use modules

# %%
from pathlib import Path

sample = Path("sample_notes.txt")
sample.write_text("Python is practical.\nData is powerful.\n")

text = sample.read_text()
print(text)
# Out:
# Python is practical.
# Data is powerful.

# %%
# Exception handling
raw = ["10", "20", "oops", "30"]
parsed = []

for item in raw:
    try:
        parsed.append(int(item))
    except ValueError:
        print(f"Skipping non-numeric value: {item}")

print("Parsed:", parsed)
# Out:
# Skipping non-numeric value: oops
# Parsed: [10, 20, 30]

# %%
# Function to safely divide two numbers
def safe_divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return "Error: Cannot divide by zero"

# Example usage
print(safe_divide(10, 2))  # 5.0
print(safe_divide(10, 0))  # Error message
# Out:
# 5.0
# Error: Cannot divide by zero
